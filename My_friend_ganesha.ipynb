# %%
import cv2
import numpy

# %%
bg=cv2.imread('paint.png')

# %%
bg[89:99,650:750]=(0,245,255)
bg[100:110,600:800]=(0,245,255)
bg[111:121,500:900]=(0,245,255)
bg[122:132,400:1000]=(0,245,255)#last crown_line

bg[133:143,500:600]=(0,128,255)#left ear
bg[144:154,510:600]=(0,128,255)
bg[155:165,520:600]=(0,128,255)
bg[166:176,530:600]=(0,128,255)
bg[177:187,540:600]=(0,128,255)
bg[188:198,550:600]=(0,128,255)
bg[199:209,560:600]=(0,128,255)
bg[210:220,570:600]=(0,128,255)
bg[221:231,580:600]=(0,128,255)
bg[232:242,590:600]=(0,128,255)

bg[133:143,800:899]=(0,128,255)#right ear
bg[144:154,800:889]=(0,128,255)
bg[155:165,800:879]=(0,128,255)
bg[166:176,800:869]=(0,128,255)
bg[177:187,800:859]=(0,128,255)
bg[188:198,800:849]=(0,128,255)
bg[199:209,800:839]=(0,128,255)
bg[210:220,800:829]=(0,128,255)
bg[221:231,800:819]=(0,128,255)
bg[232:242,800:809]=(0,128,255)

#rosary(left side)
bg[185:254,640:645]=(0,245,255)
bg[254:270,640:645]=(0,245,255)
bg[265:285,640:645]=(0,245,255)
bg[285:295,645:660]=(41,4,251)
bg[296:306,660:675]=(0,245,255)
bg[307:317,675:690]=(41,4,251)
bg[318:328,690:705]=(0,245,255)
#in between of rosary
bg[330:335,690:725]=(41,4,251)
bg[335:345,694:721]=(41,4,251)
bg[345:355,700:715]=(41,4,251)
bg[338:348,700:715]=(0,245,255)
#rosary(right side)
bg[175:285,765:770]=(0,245,255)
bg[285:295,755:770]=(41,4,251)
bg[296:306,740:755]=(0,245,255)
bg[307:317,725:740]=(41,4,251)
bg[318:328,710:725]=(0,245,255)

bg[133:143,610:790]=(255,255,255)#face
bg[144:154,620:780]=(255,255,255)
bg[155:163,625:775]=(255,255,255)#3rd line of the face
bg[164:174,630:770]=(255,255,255)
bg[175:185,640:760]=(255,255,255)
bg[186:196,650:750]=(255,255,255)
bg[197:207,660:740]=(255,255,255)
bg[208:218,670:730]=(255,255,255)
bg[219:229,680:720]=(255,255,255)#(part selected for tooth also)
bg[230:240,690:710]=(255,255,255)
bg[241:251,695:705]=(255,255,255)
bg[252:262,696:704]=(255,255,255)
bg[263:273,697:703]=(255,255,255)
bg[274:276,680:703]=(255,255,255)
bg[263:274,675:680]=(255,255,255)
bg[175:185,694:705]=(41,4,251)#red line starting from 6th row
bg[186:196,694:705]=(41,4,251)
bg[197:207,694:705]=(41,4,251)
bg[208:218,694:705]=(41,4,251)
bg[219:229,694:705]=(41,4,251)
bg[230:235,694:705]=(41,4,251)
bg[164:174,694:705]=(41,4,251)#red from starting of face(opposite start)
bg[155:163,694:705]=(41,4,251)
bg[144:154,694:705]=(41,4,251)
bg[133:143,694:705]=(41,4,251)
bg[133:143,675:685]=(41,4,251)#all covered by red line
bg[144:154,675:685]=(41,4,251)#tridant left half started
bg[154:164,675:685]=(41,4,251)
bg[154:164,685:695]=(41,4,251)#tridant left-half ended
bg[154:164,695:725]=(41,4,251)#tridant right-half started
bg[144:154,715:725]=(41,4,251)#completing right-part of tridant
bg[133:143,715:725]=(41,4,251)

bg[177:187,465:475]=(0,128,255)#left hand 
bg[188:198,462:478]=(0,128,255)
bg[199:209,459:481]=(0,128,255)
bg[210:220,456:483]=(0,128,255)
bg[221:231,453:486]=(0,128,255)
bg[232:242,450:489]=(0,128,255)
bg[243:253,448:491]=(0,245,255)
bg[254:264,446:493]=(255,255,255)
bg[265:275,448:491]=(255,255,255)
#bg[276:286,448:491]=(255,255,255)
#bg[287:297,448:491]=(255,255,255)
#bg[298:308,448:491]=(255,255,255)
#bg[309:319,448:491]=(255,255,255)
#bg[320:330,448:491]=(255,255,255)
#bg[332:342,448:491]=(255,255,255)
#bg[343:353,448:491]=(255,255,255)

bg[177:187,924:934]=(0,128,255)#Right hand 
bg[188:198,921:937]=(0,128,255)
bg[199:209,918:940]=(0,128,255)
bg[210:220,915:943]=(0,128,255)
bg[221:231,912:946]=(0,128,255)
bg[232:242,909:949]=(0,128,255)
bg[243:253,906:952]=(0,245,255)
bg[254:264,904:954]=(255,255,255)
bg[265:275,906:952]=(255,255,255)
#bg[276:286,906:952]=(255,255,255)
#bg[287:297,906:952]=(255,255,255)
#bg[298:308,906:952]=(255,255,255)
#bg[309:319,906:952]=(255,255,255)
#bg[320:330,906:952]=(255,255,255)
#bg[332:342,906:952]=(255,255,255)
#bg[343:353,906:952]=(255,255,255)

bg[354:364,448:600]=(0,128,255)#Left leg
bg[365:375,464:606]=(0,128,255)
bg[376:386,475:610]=(0,128,255)
bg[387:397,485:614]=(0,128,255)
bg[398:408,500:625]=(0,128,255)
bg[409:419,525:638]=(0,128,255)
bg[420:430,550:658]=(0,128,255)
bg[431:441,565:678]=(0,128,255)

bg[354:364,820:965]=(0,128,255)#Right leg
bg[365:375,815:956]=(0,128,255)
bg[376:386,812:942]=(0,128,255)
bg[387:397,806:937]=(0,128,255)
bg[398:408,801:926]=(0,128,255)
bg[409:419,790:913]=(0,128,255)
bg[420:430,776:893]=(0,128,255)
bg[431:441,765:878]=(0,128,255)

bg[220:229,675:680]=(192,192,192)#left-tooth(Ganesha's right tooth)

bg[219:229,720:723]=(192,192,192)#right-tooth(Ganesha's left tooth)
bg[220:229,723:725]=(192,192,192)
bg[224:229,725:732]=(192,192,192)
bg[226:229,732:734]=(192,192,192)

# %%
cv2.imshow('....OM GAN GANPATI NAMAH....',bg)
cv2.waitKey()
cv2.destroyAllWindows()
